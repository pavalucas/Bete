# %%
from sklearn import svm
import pandas as pd
import itertools
import utils
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from random import Random
from sklearn.metrics import classification_report
import load_data
import pickle

# %% [markdown]
# # Example from sklearn

# %%
X = [[0], [1], [2], [3]]
y = [0, 1, 2, 3]
clf = svm.SVC(decision_function_shape='ovr')
clf.fit(X, y)
clf.predict([[5]])
# Out:
# array([3])

# %% [markdown]
# # Parse Dia-Bete data
# Get list of relations from Dia-Bete file. The 'Relation' column is in the following format: causes|prevents, the name of the relation that this entity is the target separated by '|'. The 'Relation ID' column is in this format: 1-1[1_2]|1-19[3_2], where the first two numbers tell the ID of the first token of the source entity and the two numbers in square brackets say the entity number of the source entity and the target entity (the current entity).
#
# For each pair of words have a label if they are connected by a relation or not. Use word.isupper as the only feature for now

# %%
df = pd.read_csv('../../data/all_annotated_dataset_2022_01_27.csv', index_col=0)
file_name_list = list(df['File'].unique())
train_split = int(len(file_name_list) * 0.9)
print(train_split)
Random(42).shuffle(file_name_list)
train_files = file_name_list[:train_split]
test_files = file_name_list[train_split:]
X_train_text, y_train_text = load_data.load_relation_data_diabete(df, train_files, is_bert=True)
X_test_text, y_test_text = load_data.load_relation_data_diabete(df, test_files, is_bert=True)
# Out:
# 505
# main_resposta_0180.txt
# nutrition_resposta_0219.txt
# nutrition_resposta_0104.txt
# nutrition_resposta_0103.txt
# main_resposta_0266.txt
# main_resposta_0148.txt
# nutrition_resposta_0075.txt
# main_resposta_0076.txt
# main_resposta_0161.txt
# main_resposta_0133.txt
# main_resposta_0097.txt
# main_resposta_0119.txt
# nutrition_resposta_0157.txt
# main_resposta_0267.txt
# nutrition_resposta_0095.txt
# nutrition_resposta_0212.txt
# nutrition_resposta_0141.txt
# main_resposta_0268.txt
# main_resposta_0191.txt
# main_resposta_0075.txt
# nutrition_resposta_0112.txt
# nutrition_resposta_0184.txt
# main_resposta_0214.txt
# nutrition_resposta_0246.txt
# nutrition_resposta_0237.txt
# nutrition_resposta_0010.txt
# nutrition_resposta_0187.txt
# nutrition_resposta_0211.txt
# nutrition_resposta_0051.txt
# main_resposta_0287.txt
# nutrition_resposta_0233.txt
# nutrition_resposta_0130.txt
# nutrition_resposta_0063.txt
# main_resposta_0252.txt
# nutrition_resposta_0037.txt
# nutrition_resposta_0139.txt
# nutrition_resposta_0071.txt
# main_resposta_0022.txt
# main_resposta_0222.txt
# main_resposta_0060.txt
# nutrition_resposta_0100.txt
# main_resposta_0087.txt
# nutrition_resposta_0099.txt
# main_resposta_0179.txt
# nutrition_resposta_0152.txt
# main_resposta_0262.txt
# nutrition_resposta_0173.txt
# main_resposta_0120.txt
# main_resposta_0178.txt
# nutrition_resposta_0021.txt
# main_resposta_0246.txt
# nutrition_resposta_0019.txt
# main_resposta_0199.txt
# main_resposta_0278.txt
# main_resposta_0132.txt
# main_resposta_0183.txt
# main_resposta_0298.txt
# main_resposta_0258.txt
# main_resposta_0281.txt
# nutrition_resposta_0131.txt
# main_resposta_0212.txt
# main_resposta_0165.txt
# nutrition_resposta_0105.txt
# main_resposta_0093.txt
# main_resposta_0091.txt
# main_resposta_0144.txt
# nutrition_resposta_0150.txt
# nutrition_resposta_0119.txt
# main_resposta_0238.txt
# nutrition_resposta_0125.txt
# main_resposta_0194.txt
# main_resposta_0069.txt
# main_resposta_0117.txt
# nutrition_resposta_0058.txt
# main_resposta_0294.txt
# main_resposta_0177.txt
# main_resposta_0009.txt
# nutrition_resposta_0061.txt
# nutrition_resposta_0111.txt
# main_resposta_0052.txt
# nutrition_resposta_0235.txt
# nutrition_resposta_0229.txt
# main_resposta_0089.txt
# main_resposta_0202.txt
# main_resposta_0163.txt
# nutrition_resposta_0222.txt
# nutrition_resposta_0166.txt
# nutrition_resposta_0060.txt
# nutrition_resposta_0073.txt
# main_resposta_0228.txt
# main_resposta_0005.txt
# nutrition_resposta_0004.txt
# main_resposta_0121.txt
# main_resposta_0185.txt
# main_resposta_0141.txt
# nutrition_resposta_0203.txt
# nutrition_resposta_0195.txt
# main_resposta_0216.txt
# nutrition_resposta_0143.txt
# main_resposta_0106.txt
# main_resposta_0101.txt
# main_resposta_0043.txt
# nutrition_resposta_0093.txt
# main_resposta_0107.txt
# nutrition_resposta_0027.txt
# nutrition_resposta_0258.txt
# main_resposta_0023.txt
# main_resposta_0283.txt
# nutrition_resposta_0175.txt
# main_resposta_0241.txt
# nutrition_resposta_0240.txt
# nutrition_resposta_0200.txt
# nutrition_resposta_0247.txt
# main_resposta_0259.txt
# main_resposta_0176.txt
# nutrition_resposta_0154.txt
# nutrition_resposta_0236.txt
# main_resposta_0290.txt
# nutrition_resposta_0226.txt
# main_resposta_0154.txt
# nutrition_resposta_0092.txt
# nutrition_resposta_0230.txt
# nutrition_resposta_0138.txt
# nutrition_resposta_0069.txt
# nutrition_resposta_0133.txt
# main_resposta_0046.txt
# nutrition_resposta_0036.txt
# nutrition_resposta_0177.txt
# nutrition_resposta_0144.txt
# nutrition_resposta_0106.txt
# nutrition_resposta_0254.txt
# nutrition_resposta_0035.txt
# main_resposta_0111.txt
# main_resposta_0038.txt
# nutrition_resposta_0001.txt
# nutrition_resposta_0072.txt
# nutrition_resposta_0031.txt
# main_resposta_0020.txt
# nutrition_resposta_0180.txt
# nutrition_resposta_0171.txt
# nutrition_resposta_0052.txt
# main_resposta_0114.txt
# main_resposta_0042.txt
# main_resposta_0156.txt
# nutrition_resposta_0186.txt
# main_resposta_0292.txt
# nutrition_resposta_0076.txt
# main_resposta_0012.txt
# nutrition_resposta_0134.txt
# nutrition_resposta_0178.txt
# main_resposta_0024.txt
# main_resposta_0014.txt
# nutrition_resposta_0059.txt
# nutrition_resposta_0185.txt
# main_resposta_0188.txt
# nutrition_resposta_0174.txt
# main_resposta_0303.txt
# nutrition_resposta_0188.txt
# main_resposta_0054.txt
# main_resposta_0155.txt
# main_resposta_0181.txt
# main_resposta_0070.txt
# main_resposta_0040.txt
# nutrition_resposta_0153.txt
# nutrition_resposta_0217.txt
# nutrition_resposta_0216.txt
# nutrition_resposta_0202.txt
# nutrition_resposta_0189.txt
# main_resposta_0027.txt
# main_resposta_0201.txt
# main_resposta_0142.txt
# main_resposta_0171.txt
# nutrition_resposta_0118.txt
# nutrition_resposta_0043.txt
# main_resposta_0168.txt
# main_resposta_0157.txt
# main_resposta_0078.txt
# main_resposta_0140.txt
# nutrition_resposta_0192.txt
# nutrition_resposta_0209.txt
# main_resposta_0073.txt
# nutrition_resposta_0228.txt
# main_resposta_0063.txt
# main_resposta_0231.txt
# nutrition_resposta_0251.txt
# nutrition_resposta_0242.txt
# main_resposta_0270.txt
# main_resposta_0130.txt
# nutrition_resposta_0088.txt
# nutrition_resposta_0163.txt
# nutrition_resposta_0215.txt
# main_resposta_0280.txt
# main_resposta_0215.txt
# nutrition_resposta_0108.txt
# nutrition_resposta_0044.txt
# main_resposta_0003.txt
# main_resposta_0019.txt
# main_resposta_0193.txt
# main_resposta_0208.txt
# nutrition_resposta_0023.txt
# main_resposta_0077.txt
# nutrition_resposta_0074.txt
# main_resposta_0210.txt
# nutrition_resposta_0162.txt
# nutrition_resposta_0082.txt
# nutrition_resposta_0012.txt
# nutrition_resposta_0038.txt
# main_resposta_0213.txt
# main_resposta_0184.txt
# main_resposta_0172.txt
# main_resposta_0053.txt
# main_resposta_0067.txt
# main_resposta_0255.txt
# main_resposta_0134.txt
# main_resposta_0145.txt
# main_resposta_0245.txt
# main_resposta_0169.txt
# nutrition_resposta_0198.txt
# main_resposta_0242.txt
# main_resposta_0159.txt
# nutrition_resposta_0033.txt
# nutrition_resposta_0039.txt
# nutrition_resposta_0132.txt
# main_resposta_0064.txt
# main_resposta_0146.txt
# main_resposta_0269.txt
# nutrition_resposta_0208.txt
# main_resposta_0061.txt
# nutrition_resposta_0168.txt
# main_resposta_0173.txt
# main_resposta_0263.txt
# nutrition_resposta_0227.txt
# main_resposta_0018.txt
# main_resposta_0279.txt
# main_resposta_0218.txt
# main_resposta_0021.txt
# main_resposta_0131.txt
# nutrition_resposta_0077.txt
# nutrition_resposta_0158.txt
# nutrition_resposta_0241.txt
# main_resposta_0219.txt
# main_resposta_0236.txt
# nutrition_resposta_0114.txt
# nutrition_resposta_0068.txt
# main_resposta_0150.txt
# main_resposta_0013.txt
# main_resposta_0254.txt
# nutrition_resposta_0098.txt
# nutrition_resposta_0042.txt
# main_resposta_0016.txt
# nutrition_resposta_0181.txt
# main_resposta_0189.txt
# main_resposta_0149.txt
# main_resposta_0015.txt
# main_resposta_0248.txt
# main_resposta_0112.txt
# main_resposta_0152.txt
# nutrition_resposta_0011.txt
# main_resposta_0080.txt
# main_resposta_0250.txt
# main_resposta_0289.txt
# main_resposta_0147.txt
# nutrition_resposta_0097.txt
# nutrition_resposta_0053.txt
# main_resposta_0200.txt
# nutrition_resposta_0096.txt
# nutrition_resposta_0182.txt
# nutrition_resposta_0054.txt
# nutrition_resposta_0085.txt
# nutrition_resposta_0164.txt
# nutrition_resposta_0014.txt
# main_resposta_0247.txt
# nutrition_resposta_0015.txt
# nutrition_resposta_0006.txt
# main_resposta_0086.txt
# nutrition_resposta_0091.txt
# main_resposta_0048.txt
# main_resposta_0008.txt
# nutrition_resposta_0013.txt
# nutrition_resposta_0257.txt
# nutrition_resposta_0140.txt
# nutrition_resposta_0055.txt
# main_resposta_0227.txt
# main_resposta_0039.txt
# main_resposta_0295.txt
# nutrition_resposta_0183.txt
# nutrition_resposta_0016.txt
# main_resposta_0094.txt
# main_resposta_0304.txt
# nutrition_resposta_0147.txt
# main_resposta_0230.txt
# nutrition_resposta_0107.txt
# nutrition_resposta_0005.txt
# main_resposta_0099.txt
# nutrition_resposta_0220.txt
# main_resposta_0056.txt
# nutrition_resposta_0057.txt
# main_resposta_0207.txt
# main_resposta_0032.txt
# main_resposta_0051.txt
# nutrition_resposta_0243.txt
# nutrition_resposta_0116.txt
# main_resposta_0211.txt
# nutrition_resposta_0050.txt
# nutrition_resposta_0199.txt
# nutrition_resposta_0231.txt
# main_resposta_0050.txt
# main_resposta_0049.txt
# main_resposta_0098.txt
# main_resposta_0209.txt
# nutrition_resposta_0009.txt
# main_resposta_0125.txt
# main_resposta_0243.txt
# main_resposta_0296.txt
# main_resposta_0293.txt
# main_resposta_0068.txt
# nutrition_resposta_0048.txt
# main_resposta_0110.txt
# nutrition_resposta_0062.txt
# nutrition_resposta_0206.txt
# main_resposta_0122.txt
# main_resposta_0264.txt
# nutrition_resposta_0151.txt
# main_resposta_0170.txt
# nutrition_resposta_0221.txt
# main_resposta_0035.txt
# nutrition_resposta_0030.txt
# nutrition_resposta_0248.txt
# nutrition_resposta_0020.txt
# nutrition_resposta_0191.txt
# main_resposta_0004.txt
# nutrition_resposta_0135.txt
# nutrition_resposta_0155.txt
# nutrition_resposta_0169.txt
# nutrition_resposta_0113.txt
# main_resposta_0302.txt
# main_resposta_0011.txt
# main_resposta_0174.txt
# nutrition_resposta_0120.txt
# main_resposta_0116.txt
# nutrition_resposta_0146.txt
# main_resposta_0062.txt
# main_resposta_0232.txt
# main_resposta_0265.txt
# main_resposta_0225.txt
# nutrition_resposta_0080.txt
# nutrition_resposta_0029.txt
# nutrition_resposta_0197.txt
# nutrition_resposta_0137.txt
# nutrition_resposta_0232.txt
# main_resposta_0103.txt
# nutrition_resposta_0159.txt
# nutrition_resposta_0239.txt
# nutrition_resposta_0122.txt
# nutrition_resposta_0007.txt
# nutrition_resposta_0115.txt
# nutrition_resposta_0148.txt
# main_resposta_0085.txt
# nutrition_resposta_0256.txt
# main_resposta_0244.txt
# nutrition_resposta_0034.txt
# main_resposta_0066.txt
# main_resposta_0065.txt
# main_resposta_0273.txt
# main_resposta_0036.txt
# main_resposta_0249.txt
# main_resposta_0044.txt
# main_resposta_0041.txt
# nutrition_resposta_0160.txt
# main_resposta_0124.txt
# main_resposta_0030.txt
# main_resposta_0123.txt
# main_resposta_0158.txt
# nutrition_resposta_0136.txt
# nutrition_resposta_0101.txt
# main_resposta_0010.txt
# nutrition_resposta_0255.txt
# main_resposta_0166.txt
# nutrition_resposta_0003.txt
# main_resposta_0001.txt
# main_resposta_0272.txt
# main_resposta_0277.txt
# main_resposta_0083.txt
# main_resposta_0192.txt
# nutrition_resposta_0127.txt
# main_resposta_0102.txt
# nutrition_resposta_0190.txt
# nutrition_resposta_0089.txt
# nutrition_resposta_0179.txt
# main_resposta_0153.txt
# nutrition_resposta_0017.txt
# main_resposta_0055.txt
# main_resposta_0260.txt
# main_resposta_0092.txt
# nutrition_resposta_0087.txt
# main_resposta_0257.txt
# nutrition_resposta_0142.txt
# nutrition_resposta_0065.txt
# nutrition_resposta_0110.txt
# main_resposta_0002.txt
# nutrition_resposta_0205.txt
# nutrition_resposta_0218.txt
# main_resposta_0223.txt
# main_resposta_0151.txt
# main_resposta_0058.txt
# main_resposta_0175.txt
# nutrition_resposta_0025.txt
# nutrition_resposta_0172.txt
# nutrition_resposta_0196.txt
# nutrition_resposta_0081.txt
# main_resposta_0275.txt
# nutrition_resposta_0193.txt
# main_resposta_0059.txt
# nutrition_resposta_0066.txt
# nutrition_resposta_0123.txt
# main_resposta_0006.txt
# main_resposta_0284.txt
# main_resposta_0129.txt
# nutrition_resposta_0223.txt
# main_resposta_0240.txt
# nutrition_resposta_0121.txt
# main_resposta_0196.txt
# main_resposta_0198.txt
# nutrition_resposta_0249.txt
# nutrition_resposta_0002.txt
# main_resposta_0217.txt
# nutrition_resposta_0234.txt
# nutrition_resposta_0102.txt
# nutrition_resposta_0210.txt
# nutrition_resposta_0018.txt
# main_resposta_0079.txt
# main_resposta_0057.txt
# main_resposta_0025.txt
# nutrition_resposta_0083.txt
# nutrition_resposta_0213.txt
# main_resposta_0253.txt
# main_resposta_0261.txt
# main_resposta_0071.txt
# nutrition_resposta_0194.txt
# main_resposta_0186.txt
# main_resposta_0205.txt
# main_resposta_0299.txt
# main_resposta_0220.txt
# main_resposta_0300.txt
# nutrition_resposta_0079.txt
# main_resposta_0135.txt
# main_resposta_0276.txt
# main_resposta_0288.txt
# nutrition_resposta_0078.txt
# main_resposta_0127.txt
# nutrition_resposta_0244.txt
# main_resposta_0136.txt
# main_resposta_0074.txt
# main_resposta_0235.txt
# nutrition_resposta_0026.txt
# nutrition_resposta_0149.txt
# main_resposta_0203.txt
# main_resposta_0256.txt
# nutrition_resposta_0032.txt
# nutrition_resposta_0161.txt
# nutrition_resposta_0165.txt
# nutrition_resposta_0225.txt
# nutrition_resposta_0145.txt
# main_resposta_0291.txt
# main_resposta_0109.txt
# main_resposta_0034.txt
# main_resposta_0138.txt
# main_resposta_0206.txt
# main_resposta_0162.txt
# nutrition_resposta_0109.txt
# main_resposta_0017.txt
# nutrition_resposta_0117.txt
# main_resposta_0118.txt
# main_resposta_0029.txt
# nutrition_resposta_0094.txt
# nutrition_resposta_0090.txt
# nutrition_resposta_0128.txt
# main_resposta_0167.txt
# nutrition_resposta_0047.txt
# main_resposta_0113.txt
# main_resposta_0286.txt
# nutrition_resposta_0224.txt
# nutrition_resposta_0024.txt
# nutrition_resposta_0170.txt
# main_resposta_0139.txt
# nutrition_resposta_0207.txt
# main_resposta_0237.txt
# nutrition_resposta_0201.txt
# main_resposta_0126.txt
# nutrition_resposta_0070.txt
# main_resposta_0274.txt
# main_resposta_0088.txt
# nutrition_resposta_0204.txt
# nutrition_resposta_0008.txt
# main_resposta_0037.txt
# nutrition_resposta_0028.txt
# nutrition_resposta_0046.txt
# nutrition_resposta_0176.txt
# nutrition_resposta_0056.txt
# main_resposta_0137.txt
# nutrition_resposta_0040.txt
# main_resposta_0108.txt
# main_resposta_0182.txt
# main_resposta_0190.txt
# main_resposta_0084.txt
# main_resposta_0187.txt
# nutrition_resposta_0124.txt
# nutrition_resposta_0022.txt
# main_resposta_0233.txt
# nutrition_resposta_0253.txt
# main_resposta_0195.txt
# main_resposta_0104.txt
# nutrition_resposta_0245.txt
# main_resposta_0082.txt
# main_resposta_0297.txt
# main_resposta_0234.txt
# main_resposta_0047.txt
# main_resposta_0072.txt
# main_resposta_0197.txt
# nutrition_resposta_0067.txt
# main_resposta_0301.txt
# main_resposta_0081.txt
# nutrition_resposta_0084.txt
# main_resposta_0128.txt
# nutrition_resposta_0167.txt
# main_resposta_0045.txt
# main_resposta_0271.txt
# nutrition_resposta_0049.txt
# nutrition_resposta_0064.txt
# main_resposta_0100.txt
# nutrition_resposta_0086.txt
# main_resposta_0095.txt
# nutrition_resposta_0252.txt
# nutrition_resposta_0041.txt
# main_resposta_0221.txt
# main_resposta_0160.txt
# nutrition_resposta_0238.txt
# nutrition_resposta_0045.txt
# nutrition_resposta_0250.txt
# main_resposta_0164.txt
# main_resposta_0007.txt
# main_resposta_0285.txt
# nutrition_resposta_0156.txt
# main_resposta_0226.txt
# nutrition_resposta_0126.txt
# main_resposta_0204.txt
# main_resposta_0028.txt
# nutrition_resposta_0214.txt
# main_resposta_0239.txt
# main_resposta_0224.txt
# main_resposta_0096.txt
# main_resposta_0031.txt
# main_resposta_0033.txt
# nutrition_resposta_0129.txt
# main_resposta_0090.txt
# main_resposta_0105.txt
# main_resposta_0143.txt
# main_resposta_0229.txt
# main_resposta_0251.txt
# main_resposta_0282.txt
# main_resposta_0026.txt
# main_resposta_0115.txt

# %% [markdown]
# # Run SVM

# %%
vectorizer = TfidfVectorizer(analyzer = "word", binary = False, 
                             ngram_range=(3,3))
# vectorizer = CountVectorizer(analyzer = "word", binary = False, 
#                              ngram_range=(3,3))

# %%
print(f'Len X train: {len(X_train_text)}')
X_train = vectorizer.fit_transform(X_train_text)
y_train = [utils.relation2id[elem] for elem in y_train_text]
clf = svm.SVC(decision_function_shape='ovr')
clf.fit(X_train, y_train)
# Out:
# Len X train: 854
# SVC()

# %%
print(f'Len X test: {len(X_test_text)}')
X_test = vectorizer.transform(X_test_text)
y_test = [utils.relation2id[elem] for elem in y_test_text]
y_pred = clf.predict(X_test)
labels = list(range(1, len(utils.RELATIONS)))
target_names = utils.RELATIONS[1:]
print(classification_report(y_test, y_pred, labels=labels, target_names=target_names))
# Out:
# Len X test: 117
#               precision    recall  f1-score   support
#
#       causes       0.00      0.00      0.00         6
#     prevents       0.00      0.00      0.00         4
#       treats       0.71      0.71      0.71        14
#          has       0.85      1.00      0.92        86
#    diagnoses       1.00      0.29      0.44         7
#  complicates       0.00      0.00      0.00         0
#
#    micro avg       0.84      0.84      0.84       117
#    macro avg       0.43      0.33      0.35       117
# weighted avg       0.77      0.84      0.79       117
# /home/lucas/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucas/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucas/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucas/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucas/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lucas/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Create BERT RE data

# %%
df_train = load_data.create_bert_re_df(X_train_text, y_train_text)
df_test = load_data.create_bert_re_df(X_test_text, y_test_text)
# df_train = df_train[:150]
# df_test = df_test[:100]
df_train
# Out:
#                                                   sents         relations  \
# 0     em relação a [E2]gelatina[/E2] , caso ela seja...        has(e1,e2)
# 1     a [E1]glicada[/E1] é um exame chamado de " hem...  diagnoses(e1,e2)
# 2     a glicada é um exame chamado de " [E1]hemoglob...  diagnoses(e1,e2)
# 3     a glicada é um exame chamado de " hemoglobina ...             Other
# 4     a [E2]glicada[/E2] é um exame chamado de " hem...             Other
# ...                                                 ...               ...
# 1466  quem tem diabetes tem uma chance maior de ter ...             Other
# 1467  quem tem diabetes tem uma chance maior de ter ...             Other
# 1468  quem tem diabetes tem uma chance maior de ter ...             Other
# 1469  quem tem diabetes tem uma chance maior de ter ...             Other
# 1470  quem tem diabetes tem uma chance maior de ter ...             Other
#
#       relations_id
# 0                4
# 1                5
# 2                5
# 3                0
# 4                0
# ...            ...
# 1466             0
# 1467             0
# 1468             0
# 1469             0
# 1470             0
#
# [1471 rows x 3 columns]

# %%
df_test
# Out:
#                                                  sents         relations  \
# 0    a pele dos pés de pessoas com [E2]diabetes[/E2...   prevents(e1,e2)
# 1    a pele dos pés de pessoas com diabetes costuma...   prevents(e1,e2)
# 2    a pele dos pés de pessoas com diabetes costuma...   prevents(e1,e2)
# 3    a pele dos pés de pessoas com [E1]diabetes[/E1...             Other
# 4    é recomendado que se calibre o [E1]glicosímetr...  diagnoses(e1,e2)
# ..                                                 ...               ...
# 191  níveis - que é o seu caso - podem levar a uma ...     treats(e1,e2)
# 192  níveis - que é o seu caso - podem levar a uma ...     treats(e1,e2)
# 193  níveis - que é o seu caso - podem levar a uma ...             Other
# 194  níveis - que é o seu caso - podem levar a uma ...             Other
# 195  [E2]níveis[/E2] - que é o seu caso - podem lev...             Other
#
#      relations_id
# 0               2
# 1               2
# 2               2
# 3               0
# 4               5
# ..            ...
# 191             3
# 192             3
# 193             0
# 194             0
# 195             0
#
# [196 rows x 3 columns]

# %%
pickle.dump(df_train, open('../../../BERT-Relation-Extraction/data/df_train_bete.pkl', 'wb'))
pickle.dump(df_test, open('../../../BERT-Relation-Extraction/data/df_test_bete.pkl', 'wb'))

# %% [markdown]
# # Parse eHealth data

# %%
ehealth_df_train = load_data.load_relation_data_ehealth('../../data/eHealthKD/original/ref/training/input_multilingual.json')
ehealth_df_test = load_data.load_relation_data_ehealth('../../data/eHealthKD/original/ref/develop/input_multilingual.json')
print(f'Len eHealth train: {len(ehealth_df_train)}')
print(f'Len eHealth test: {len(ehealth_df_test)}')
ehealth_df_train
# Out:
# Len eHealth train: 20571
# Len eHealth test: 1658
#                                                    sents          relations  \
# 0      La presencia del [E1]gen[/E1] de células falci...  in-context(e1,e2)
# 1      La [E1]presencia[/E1] del [E2]gen de células f...     subject(e1,e2)
# 2      La [E1]presencia[/E1] del gen de células falci...     same-as(e1,e2)
# 3      La [E1]presencia[/E1] del [E2]gen[/E2] de célu...     subject(e1,e2)
# 4      La [E1]presencia[/E1] del gen de células falci...              Other
# ...                                                  ...                ...
# 20566  Durante la [E1]noche[/E1] el edificio de Venez...              Other
# 20567  Durante la [E1]noche[/E1] el edificio de Venez...              Other
# 20568  Durante la [E1]noche[/E1] el edificio de Venez...              Other
# 20569  Durante la [E1]noche[/E1] el edificio de Venez...              Other
# 20570  Durante la noche el [E1]edificio[/E1] de Venez...              Other
#
#        relations_id
# 0                 6
# 1                 9
# 2                13
# 3                 9
# 4                 0
# ...             ...
# 20566             0
# 20567             0
# 20568             0
# 20569             0
# 20570             0
#
# [20571 rows x 3 columns]

# %%
pickle.dump(ehealth_df_train, open('../../../BERT-Relation-Extraction/data/df_train_ehealth.pkl', 'wb'))
pickle.dump(ehealth_df_test, open('../../../BERT-Relation-Extraction/data/df_test_ehealth.pkl', 'wb'))
